# %% [markdown]
# # Analyzing Census ACS data for veterans trends
# Done in pandas
#
# Alan Hovorka | The Villages Daily Sun

# %%
from glob import glob
import os
import pandas as pd
import numpy as np
# %matplotlib inline

#import the library called glob. This targets a file folder and grabs all of the files in there.
#With glob, we can quickly create a list of file names that we can parse data for
#glob also supports wildcards so that we don't have to type exact file names. Just specify a general directory and a general file type. 
#When working with small directories, it's OK to generalize with a wildcard. 
#Greater volume of files and larger files require you to be more specific with your globs because it'll take way longer to generate the list.
#pandas, numpy and matplotlib allow us to manipulate the data and visualize it.
#The OS lib is a "module provides a portable way of using operating system dependent functionality."

# %%
acs = glob("data/*/*.csv", recursive = True)
year_list = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
col_list = []
yrs = []

for d in year_list:
    print(d)
for d in acs:
    print(d)

#glob the directory with the csvs into a list
#create an empty dataframe for our eventual merged/concat dataset of census 
#estimates for 12 years
# print(acs[0])
# len(year_list)
# len(acs)
# Out:
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# data/acs_1_yr_vet_status_est/vets_2005_acs.csv
# data/acs_1_yr_vet_status_est/vets_2006_acs.csv
# data/acs_1_yr_vet_status_est/vets_2007_acs.csv
# data/acs_1_yr_vet_status_est/vets_2008_acs.csv
# data/acs_1_yr_vet_status_est/vets_2009_acs.csv
# data/acs_1_yr_vet_status_est/vets_2010_acs.csv
# data/acs_1_yr_vet_status_est/vets_2011_acs.csv
# data/acs_1_yr_vet_status_est/vets_2012_acs.csv
# data/acs_1_yr_vet_status_est/vets_2013_acs.csv
# data/acs_1_yr_vet_status_est/vets_2014_acs.csv
# data/acs_1_yr_vet_status_est/vets_2015_acs.csv
# data/acs_1_yr_vet_status_est/vets_2016_acs.csv

# %% [markdown]
# ### List of csvs is:
# #### Index 0 = 2005 data and Index = -1 is 2016

# %%
# print(acs[0])

# %% [markdown]
# #### This next section pulls the csv in, drops margin of estimate and percent columns and creates a trimmed csv.

# %%
df = pd.read_csv(acs[0], header=[0,1])
# df.head()
cols = df.filter(regex='\_MOE_').columns
# print(cols)
df.drop(cols, axis=1, inplace=True)
# df.head()
cols2 = df.filter(regex='\ PERCENT').columns
#print(cols2)
df.drop(cols2, axis=1, inplace=True)
# print(df.dtypes)
# df.to_csv('trimmed.csv', index = False)

# %% [markdown]
# #### Declare a function to create a list of years that is the length of the csv's states/territories. This list is used to create identifiable years across 12 csv files for eventual time series analysis.

# %%
def yearcolmaker(y):
    yrs = [y]*52
    return yrs

yrs = yearcolmaker(2005)
# df.info()
print(yrs)
# Out:
# [2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005]

# %%
#Insert a column for the year list we just created.
df.insert(2, 'year', yrs)

# %%
df.head()
#Check to make sure it appended correctly.
# Out:
#         GEO.id GEO.id2  year GEO.display-label  \
#             Id     Id2               Geography
# 0  0400000US01       1  2005           Alabama
# 1  0400000US02       2  2005            Alaska
# 2  0400000US04       4  2005           Arizona
# 3  0400000US05       5  2005          Arkansas
# 4  0400000US06       6  2005        California
#
#                                            HC01_EST_VC01  \
#   Total; Estimate; Civilian population 18 years and over
# 0                                            3344721
# 1                                             446969
# 2                                            4238996
# 3                                            2023819
# 4                                           25543447
#
#                                               HC02_EST_VC01  \
#   Veterans; Estimate; Civilian population 18 years and over
# 0                                             403950
# 1                                              74482
# ...

# %%
df2=df.dropna(axis=1, how='all')
# Drops columns that contain only null values

# %% [markdown]
# ## Now let's take the above code and make it scalable in a for function that creates a brand new dataframe with all 12 years of Census ACS data in one spot.

# %%
df_list = []
#declare an empty list for our list of dataframes
#declare a for loop the has two variables and two iterable lists. 
#zip allows you to have multiple iterables in the declaration of the for loop.
for f,g in zip(acs,year_list):
    df3 = pd.read_csv(f, header=0, skiprows=1)
    #df3 is a variable that holds the current dataframe the loop is iterating through
    #When it reaches the end of the loop, the frame is added to df_list and the loop starts over, overwriting the previous dataframe
    cols = df3.filter(regex='\_MOE_').columns
    #declare a column varaible that collects a list of column names that fit the filter criteria. We drop these columns because they're not useful
    #As I understand it, Pandas can only handle one filter request at a time. You must filter -> drop -> filter -> drop.
    df3.drop(cols, axis=1, inplace=True)
    cols2 = df3.filter(regex='\ PERCENT').columns
    df3.drop(cols2, axis=1, inplace=True)
    cols3 = df3.filter(regex='.Percent;').columns
    df3.drop(cols3, axis=1, inplace=True)
    df3.dropna(axis=1, how='all',inplace=True)
    #call our year list creating function. Here we iterate through a list of years that matches our list of csvs.
    #We want to insert a column that adds a year value to each row
    yrs = yearcolmaker(g)
    df3.insert(2,'year',yrs)
    df3.info()
    df_list.append(df3)
    #Here we add the results of the loop into a list and continue iterating until there are no csv files left
    # https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 212 entries, Id to Nonveterans; Margin of Error; DISABILITY STATUS - Civilian population 18 years and over - With any disability
# dtypes: float64(158), int64(52), object(2)
# memory usage: 86.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 212 entries, Id to Nonveterans; Margin of Error; DISABILITY STATUS - Civilian population 18 years and over - With any disability
# dtypes: float64(158), int64(52), object(2)
# memory usage: 86.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 214 entries, Id to Nonveterans; Margin of Error; DISABILITY STATUS - Civilian population 18 years and over - With any disability
# dtypes: float64(160), int64(52), object(2)
# memory usage: 87.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# ...

# %%
df_list[6].head()
# Out:
#             Id  Id2  year   Geography  \
# 0  0400000US01    1  2011     Alabama
# 1  0400000US02    2  2011      Alaska
# 2  0400000US04    4  2011     Arizona
# 3  0400000US05    5  2011    Arkansas
# 4  0400000US06    6  2011  California
#
#    Total; Estimate; Civilian population 18 years and over  \
# 0                                            3662910
# 1                                             517799
# 2                                            4842927
# 3                                            2221409
# 4                                           28292703
#
#    Total; Margin of Error; Civilian population 18 years and over  \
# 0                                               3327
# 1                                               1913
# 2                                               2377
# 3                                               1882
# 4                                               5322
#
#    Veterans; Estimate; Civilian population 18 years and over  \
# ...

# %%
print(year_list[6])
# Out:
# 2011

# %% [markdown]
# #### We've successfully created a list of cleaned dataframes. Each dataframes has a column to identify which year it is. Now we need to merge the data. In theory we could the data at the start and then filter it.

# %%
df_cc = pd.concat(df_list)

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 624 entries, 0 to 51
# Columns: 812 entries, Geography to year
# dtypes: float64(796), int64(14), object(2)
# memory usage: 3.9+ MB

# %%
df_cc.to_csv('concated.csv', index = False)

# %%
df_list2 = []
for f,g in zip(acs,year_list):
    df3 = pd.read_csv(f, header=0, skiprows=1)
    yrs = yearcolmaker(g)
    df3.insert(2,'year',yrs)
    df3.info()
    df_list2.append(df3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 244 entries, Id to Nonveterans; Margin of Error; PERCENT IMPUTED - Period of service for the civilian veteran population 18 years and over
# dtypes: float64(190), int64(52), object(2)
# memory usage: 99.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 244 entries, Id to Nonveterans; Margin of Error; PERCENT IMPUTED - Period of service for the civilian veteran population 18 years and over
# dtypes: float64(190), int64(52), object(2)
# memory usage: 99.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Columns: 250 entries, Id to Nonveterans; Margin of Error; PERCENT IMPUTED - Period of service for the civilian veteran population 18 years and over
# dtypes: float64(196), int64(52), object(2)
# memory usage: 101.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# ...

# %%
df_cc2 = pd.concat(df_list2)

# %%
df_cc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 624 entries, 0 to 51
# Columns: 1000 entries, Geography to year
# dtypes: float64(984), int64(14), object(2)
# memory usage: 4.8+ MB

# %%
df_cc2.to_csv('concated_unfiltered.csv', index = False)

# %% [markdown]
# ## Concatted data observations
# Tables for 2005-2006, near identical structure
# Tables for 2007-2014, same number of columns, varying structure
# Tables for 2015-2016, near identical structure
#
# Here's how the columns vary:
#
#     2005-2006 = the same
#     2007-2010 = the same
#     2010-2016 = the same

# %%
cols = df_cc2.filter(regex='\_MOE_').columns
df_cc2.drop(cols, axis=1, inplace=True)
cols2 = df3.filter(regex='\ PERCENT').columns
df_cc2.drop(cols2, axis=1, inplace=True)
cols3 = df_cc2.filter(regex='.Percent;').columns
df_cc2.drop(cols3, axis=1, inplace=True)

# %%
#Filter the concatted data
df_cc2.dropna(axis=1, how='all',inplace=True)

# %%
df_cc2.head()
# Out:
#     Geography           Id  Id2  Nonveterans; Estimate; AGE - 18 to 34 years  \
# 0     Alabama  0400000US01    1                                          NaN
# 1      Alaska  0400000US02    2                                          NaN
# 2     Arizona  0400000US04    4                                          NaN
# 3    Arkansas  0400000US05    5                                          NaN
# 4  California  0400000US06    6                                          NaN
#
#    Nonveterans; Estimate; AGE - 35 to 54 years  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Nonveterans; Estimate; AGE - 55 to 64 years  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
df_cc2.to_csv('concated_refiltered.csv', index = False)

# %% [markdown]
# ## Editing the joined unfiltered data (WORK IN PROGRESS, MAYBE GO BACK AND READD THE MOE AND PERCENT IMPUTED)
#
# Here are the steps I took to fix the mess of columns in the unfiltered data. I did this by hand in Excel (please don't kill me).
#
# There are exactly 1,000 columns. This will be lengthy. The Census has columns with the same name that vary slightly. To simplify this dataset, I deleted the margin of error and percent imputed columns. I understand that they might be valuable to some, but I skimmed through them and didn't see any glaring concerns. A lot of the steps here will be to merge like columns or to mass delete columns.
#
# Note: columns labelled percent ARE helpful. For 2015 and 2016, the Census changed some labelling in its data and some of the useful data is contained in these somewhat nondescript columns.
#
# Also, some percentage columns change to integers. After we merge and purge, we'll convert columns. These percentage columns are not properly labelled. Please refer to 2015 and 2016 individual exports from Census to ascertain which category (total, veteran, nonveteran) the percentage belongs to.
#
# I moved the year column to the very first column.
#
# Moved the "Nonveterans; Estimate; Civilian population 18 years and over" column after the id columns.
#
# #### Combine:
#     "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years" and "Nonveterans; Estimate; AGE - 18 to 34 years".
#     Delete empty column "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years".
#
# #### Combine:
#     "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years" and "Nonveterans; Estimate; AGE - 35 to 54 years".
#     Delete empty column "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years".
#
# #### Combine:
#     "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years" and "Nonveterans; Estimate; AGE - 55 to 64 years".
#     Delete empty column "Nonveterans; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years".
#
# Repeat the above steps for age buckets through 75 and over, which is the last age bucket.
#
# #### Delete empty columns:
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - Gulf War (8/1990 to 8/2001) veterans
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - Gulf War (9/2001 or later) veterans
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - Gulf War veterans
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - Korean War veterans
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - Vietnam era veterans
#     Nonveterans; Estimate; Civilian population 18 years and over - PERIOD OF SERVICE - World War II veterans
#
# #### Delete Margin of Error columns for nonveterans.
#     There are a lot of them. You can do this in pandas if you want. I preferred to make sure every column I purged was correct.
#     We'll repeat this for total and veterans as well.
#
# #### Move columns around
#
#     Move like nonveteran columns near each other for easier comparison of differences and similarities. For example, all education columns should be near each other.
#
# #### Combine
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over
#
#     Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over
#
#     Delete:
#     Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over
#
# #### Combine
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Bachelor's degree or higher
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Bachelor's degree or higher
#
#     Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Bachelor's degree or higher
#
#     Delete:
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Bachelor's degree or higher
#
#     Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Bachelor's degree or higher
#
#
# #### Combine
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - High school graduate (includes equivalency)
#
#     Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - High school graduate (includes equivalency)
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - High school graduate (includes equivalency)
#
#     Delete:
#         Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - High school graduate (includes equivalency)
#
#     Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - High school graduate (includes equivalency)
#
# #### Combine
#
#       Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Less than high school graduate
#
#       Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Less than high school graduate
#
#       Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Less than high school graduate
#
#       Delete:
#       Nonveterans; Estimate; Civilian population 18 years and over - EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Less than high school graduate
#
#       Nonveterans; Estimate; EDUCATIONAL ATTAINMENT - Civilian population 25 years and over - Less than high school graduate
#
# #### Combine
#
#     Repeat the above for some college/associate degree columns
#
# #### Combine
#     Nonveterans; Estimate; Hispanic or Latino (of any race)
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - Hispanic or Latino (of any race)
#
#     Delete:
#     Nonveterans; Estimate; Hispanic or Latino (of any race)
#
# #### Combine
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race
#
#     Delete:
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - American Indian and Alaska Native alone
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native
#
#     Delete:
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - American Indian and Alaska Native alone
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Asian alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian
#
#     Delete:
#         Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Asian alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Black or African American alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American
#     Delete:
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Black or African American alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American
#
# #### Combine
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Native Hawaiian and Other Pacific Islander alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander
#     Delete:
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Native Hawaiian and Other Pacific Islander alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Some other race alone
#
#     Delete:
#
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Some other race alone
#
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race - White
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - White alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White
#
#     Delete:
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - White alone
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White
#
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
#
#     Delete:
#     Nonveterans; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - White alone, not Hispanic or Latino
#     Nonveterans; Estimate; White alone, not Hispanic or Latino
#
#     Delete:
#     Nonveterans; Estimate; White alone, not Hispanic or Latino
#
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - SEX - Female
#     Nonveterans; Estimate; SEX - Female
#
#     Delete:
#     Nonveterans; Estimate; SEX - Female
#
# #### Combine
#
#     Nonveterans; Estimate; Civilian population 18 years and over - SEX - Male
#     Nonveterans; Estimate; SEX - Male
#     Delete:
#     Nonveterans; Estimate; SEX - Male
#
# #### Useless
#
# Nonveterans; Estimate; Civilian population 18 years and over - RACE AND HISPANIC OR LATINO ORIGIN - One race
#
# This column is not helpful. It does not contain useful information. Filled with null values.
#
# #### Combine
#
#     Nonveterans; Estimate; EMPLOYMENT STATUS - Civilian population 18 to 64 years - Labor force participation rate
#     Nonveterans; Estimate; EMPLOYMENT STATUS - Labor force participation rate![image.png](attachment:image.png)
#     2015 and 2016: Percent; Estimate; EMPLOYMENT STATUS - Civilian labor force 18 to 64 years - Unemployment rate
#     Delete:
#         Nonveterans; Estimate; EMPLOYMENT STATUS - Labor force participation rate![image.png](attachment:image.png)
#
# Follow this same pattern for all employment data.
#
# #### Combine
#
#     Total; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years	Total; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years	Total; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years	Total; Estimate; Civilian population 18 years and over - AGE - 65 to 74 years	Total; Estimate; Civilian population 18 years and over - AGE - 75 years and over
#     Total; Estimate; AGE - 18 to 34 years	Total; Estimate; AGE - 35 to 54 years	Total; Estimate; AGE - 55 to 64 years	Total; Estimate; AGE - 65 to 74 years	Total; Estimate; AGE - 75 years and over![image.png](attachment:image.png)
#     Delete:
#     Total; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years	Total; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years	Total; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years	Total; Estimate; Civilian population 18 years and over - AGE - 65 to 74 years	Total; Estimate; Civilian population 18 years and over - AGE - 75 years and over
#
# #### Combine
#     Veterans; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 65 to 74 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 75 years and over
#     Veterans; Estimate; AGE - 18 to 34 years	Veterans; Estimate; AGE - 35 to 54 years	Veterans; Estimate; AGE - 55 to 64 years	Veterans; Estimate; AGE - 65 to 74 years	Veterans; Estimate; AGE - 75 years and over
#     Delete:
#         Veterans; Estimate; Civilian population 18 years and over - AGE - 18 to 34 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 35 to 54 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 55 to 64 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 65 to 74 years	Veterans; Estimate; Civilian population 18 years and over - AGE - 75 years and over
#
# #### Combine
#
# #### Combine
#
# #### Combine
#
# #### Combine
#
# #### Combine
#
#
# ## Adjust the median income data and merge into one column. Adjust for 2016 inflation because that's the latest year and the year that we're making our time series comparison to.
#     Download the raw CPI data
#     https://data.bls.gov/pdq/SurveyOutputServlet
#     Use this link to get the inflation formula.
#     https://www.maa.org/press/periodicals/loci/joma/the-consumer-price-index-and-inflation-calculate-and-graph-inflation-rates

# %% [markdown]
# # Analyze the data

# %%
clean = "data/cleaned.csv"
cdf = pd.read_csv(clean, header=0)
#this data is a subset of the above data. I'm on deadline and couldn't clean the whole dataset. A project for another time.

# %%
cdf.head()
# Out:
#    year   Geography           Id  Id2  total_pop  total_18_34  total_35_54  \
# 0  2005     Alabama  0400000US01    1    3344721         29.6         38.5
# 1  2005      Alaska  0400000US02    2     446969         31.0         45.2
# 2  2005     Arizona  0400000US04    4    4238996         32.5         36.5
# 3  2005    Arkansas  0400000US05    5    2023819         29.7         37.5
# 4  2005  California  0400000US06    6   25543447         32.4         40.1
#
#    total_55_64  total_65_74  total_75_up        ...          \
# 0         14.8          9.7          7.4        ...
# 1         14.4          5.9          3.5        ...
# 2         13.6          9.6          7.7        ...
# 3         14.8         10.2          7.7        ...
# 4         13.0          7.6          6.9        ...
#
#    total_employ_status_civ_pop  total_lab_part_rate  nonvet_labor_force  \
# 0                      2772037                 73.1             1829673
# ...

# %%
cdf.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 55 columns):
# year                            624 non-null int64
# Geography                       624 non-null object
# Id                              624 non-null object
# Id2                             624 non-null int64
# total_pop                       624 non-null int64
# total_18_34                     624 non-null float64
# total_35_54                     624 non-null float64
# total_55_64                     624 non-null float64
# total_65_74                     624 non-null float64
# total_75_up                     624 non-null float64
# vet_total                       624 non-null int64
# vet_18_34                       624 non-null float64
# vet_35_54                       624 non-null float64
# vet_55_64                       624 non-null float64
# vet_65_74                       624 non-null float64
# vet_75_up                       624 non-null float64
# ...

# %%
pd.options.display.max_rows = 630

# %%
cdf1 = cdf[['year','Geography','total_pop','vet_total','vet_attain','total_bach_higher','vet_bach_higher','vet_less_hs','total_unemploy_rate','vet_unemploy_rate']]

# %%
cdf1.head()
# Out:
#    year   Geography  total_pop  vet_total  vet_attain  vet_bach_higher  \
# 0  2005     Alabama    3344721     403950      396968             22.8
# 1  2005      Alaska     446969      74482       71266             25.9
# 2  2005     Arizona    4238996     538880      528459             28.7
# 3  2005    Arkansas    2023819     259304      253426             19.2
# 4  2005  California   25543447    2193336     2150540             31.2
#
#    vet_less_hs  vet_unemploy_rate
# 0         12.3                5.4
# 1          6.3                5.7
# 2          8.3                4.9
# 3         13.2                6.0
# 4          7.8                5.4

# %%
cdf1[(cdf1['Geography'] == 'Florida' ) | (cdf1['Geography'] == 'Texas') | (cdf1['Geography'] == 'California')].total_pop.pct_change().reset_index().sort_values(['total_pop'],ascending=False)
# Out:
#     index  total_pop
# 3      56   0.684935
# 6     108   0.597336
# 9     160   0.584191
# 15    264   0.569132
# 12    212   0.564330
# 18    316   0.548748
# 21    368   0.539560
# 24    420   0.529147
# 27    472   0.528124
# 30    524   0.513933
# 33    576   0.489448
# 29    511   0.251351
# 32    563   0.251297
# 26    459   0.248681
# 35    615   0.248515
# 23    407   0.243575
# 20    355   0.240192
# 17    303   0.235239
# 14    251   0.234092
# 11    199   0.226190
# 8     147   0.214442
# 5      95   0.207469
# 2      43   0.196420
# 34    581  -0.453777
# 31    529  -0.461156
# 28    477  -0.465271
# 25    425  -0.467023
# 22    373  -0.467443
# 19    321  -0.469401
# 16    269  -0.470086
# 13    217  -0.473341
# 10    165  -0.476137
# 7     113  -0.476388
# 4      61  -0.476796
# 1       9  -0.479748
# 0       4        NaN

# %%
cdf.groupby(["year","Geography"]).vet_total.sum().reset_index().sort_values(["year","vet_total"], ascending=False)

# %% [markdown]
# ### Various notes from other people
# If the columns have the same naming scheme you could write some code that simplifies a single table, then use a for loop to do that process each table in a for loop before combining them.
#
# Basically, you have a list of filenames and years, loop through each filename/year and create a simplified version of the table and put add it to a list then call pd.concat([list of tables]) to bind all the rows together
# But, there are a bunch of other ways to do it. It sort of depends on how consistent the data is over time
#
# My thought is you need to loop through each filename, pick out the columns you need, add a column for the year and add it to a list. After that you can smoosh it together with `pd.concat(list)`

# %% [markdown]
# #### Pandas snippets

# %%
# Some helpful pandas snippets 
# https://gist.github.com/bsweger/e5817488d161f37dcbd2
# Get rid of non-numeric values throughout a DataFrame:
# for col in refunds.columns.values:
#   refunds[col] = refunds[col].replace('[^0-9]+.-', '', regex=True)

# %%
# Concatenate two DataFrame columns into a new, single column
# (useful when dealing with composite keys, for example)
# (h/t @makmanalp for improving this one!)
# df['newcol'] = df['col1'].astype(str) + df['col2'].astype(str)

# %%
# Create a DataFrame from a Python dictionary
# df = pd.DataFrame(list(a_dictionary.items()), columns = ['column1', 'column2'])
