# %%
import os
import requests
import json
import pandas as pd
import numpy as np

# %%
r = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?state%5Bid%5D=FL")
nonprof= r.json()
#request Florida nonprofit data from ProPublica's Nonprofit explorer API
print(nonprof)
#Returns 43,941 Florida nonprofits/charities
#Narrow down to Lady Lake, Wildwood, The Villages, etc.
# Out:
# {'total_results': 43941, 'organizations': [{'ein': 562342625, 'strein': '56-2342625', 'name': '1 SOSFS DEFENDERS ASSOCIATION', 'sub_name': '1 SOSFS DEFENDERS ASSOCIATION', 'city': 'HURLBURT FLD', 'state': 'FL', 'ntee_code': None, 'raw_ntee_code': None, 'subseccd': 3, 'has_subseccd': True, 'have_filings': True, 'have_extracts': False, 'have_pdfs': True, 'score': 4.2835336}, {'ein': 593068740, 'strein': '59-3068740', 'name': '100 BLACK MEN OF PENSACOLA INC', 'sub_name': '100 BLACK MEN OF PENSACOLA INC', 'city': 'PENSACOLA', 'state': 'FL', 'ntee_code': 'S82Z', 'raw_ntee_code': 'S82Z', 'subseccd': 3, 'has_subseccd': True, 'have_filings': True, 'have_extracts': False, 'have_pdfs': True, 'score': 4.2835336}, {'ein': 591756721, 'strein': '59-1756721', 'name': '100 CLUB OF SOUTH PALM BEACH COUNTY INC', 'sub_name': '100 CLUB OF SOUTH PALM BEACH COUNTY INC', 'city': 'DEERFIELD BCH', 'state': 'FL', 'ntee_code': None, 'raw_ntee_code': None, 'subseccd': 3, 'has_subseccd': True, 'have_filings': Tr
# ...

# %%
# df = pd.DataFrame([[d['v'] for d in x['c']] for x in j['rows']],
#                   columns=[d['label'] for d in j['cols']])
