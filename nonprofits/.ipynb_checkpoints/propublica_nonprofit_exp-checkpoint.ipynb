# %%
import os
import time
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint as pp
# %matplotlib inline

# %%
locations = ['The Villages', 'Lady Lake', 'Wildwood', 'Busnell', 'Center Hill','Webseter','Coleman', 'Leesburg', 'Fruitland Park', 'Mt. Dora', 'Belleville', 'Summerfield'] 

baseurl = "https://projects.propublica.org/nonprofits/api/v2/search.json?state%5Bid%5D=FL&page="
r = requests.get(baseurl)
rawdata = r.json()
nonprof = rawdata['organizations']
df = pd.DataFrame(nonprof)
for page in range(1, rawdata['num_pages']):
    print("Fetching " + str(page))
    r = requests.get(baseurl + str(page))
    rawdata = r.json()
    nonprof = rawdata['organizations']
    dfnew = pd.DataFrame(nonprof)
    df = df.append(dfnew)
df.shape
#request Florida nonprofit data from ProPublica's Nonprofit explorer API
# print(nonprof)
#Returns 43,941 Florida nonprofits/charities
#Narrow down to Lady Lake, Wildwood, The Villages, etc.
# Out:
# [{'city': 'MIAMI',
#   'ein': 593237477,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVENTIST CONGREGATION OF THE PROMISE INC',
#   'ntee_code': 'X99Z',
#   'raw_ntee_code': 'X99Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3237477',
#   'sub_name': 'ADVENTIST CONGREGATION OF THE PROMISE INC',
#   'subseccd': 3},
#  {'city': 'ALTAMONTE SPG',
#   'ein': 266422966,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVENTIST HEALTH SYSTEM AFFILIATE BENEFIT TR',
#   'ntee_code': 'E112',
#   'raw_ntee_code': 'E112',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-6422966',
#   'sub_name': 'ADVENTIST HEALTH SYSTEM AFFILIATE BENEFIT TR',
#   'subseccd': 3},
#  {'city': 'ORLANDO',
#   'ein': 593069793,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVENTIST UNIVERSITY OF HEALTH SCIENCES INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3069793',
#   'sub_name': 'ADVENTIST UNIVERSITY OF HEALTH SCIENCES INC',
#   'subseccd': 3},
#  {'city': 'PALM HARBOR',
#   'ein': 272317081,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVENTURE LEARNING MISSIONS INC',
#   'ntee_code': 'X20',
#   'raw_ntee_code': 'X20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-2317081',
#   'sub_name': 'ADVENTURE LEARNING MISSIONS INC',
#   'subseccd': 3},
#  {'city': 'GAINESVILLE',
#   'ein': 208318817,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVERTISING FEDERATION OFGAINESVILLE FLORIDA INC',
#   'ntee_code': 'S41',
#   'raw_ntee_code': 'S41',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-8318817',
#   'sub_name': 'ADVERTISING FEDERATION OFGAINESVILLE FLORIDA INC',
#   'subseccd': 6},
#  {'city': 'ORMOND BEACH',
#   'ein': 223871616,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVISSORY COMMISSION ON TEXTBOOK SPECIFICATIONS INC',
#   'ntee_code': 'S41',
#   'raw_ntee_code': 'S41',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '22-3871616',
#   'sub_name': 'ADVISSORY COMMISSION ON TEXTBOOK SPECIFICATIONS INC ',
#   'subseccd': 6},
#  {'city': 'SURFSIDE',
#   'ein': 812088798,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVOCACY PARTNERS TEAM INC',
#   'ntee_code': 'I80',
#   'raw_ntee_code': 'I80',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '81-2088798',
#   'sub_name': 'ADVOCACY PARTNERS TEAM INC',
#   'subseccd': 3},
#  {'city': 'OCALA',
#   'ein': 592217524,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVOCACY RESOURCE CENTER MARION INC',
#   'ntee_code': 'P80',
#   'raw_ntee_code': 'P80',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-2217524',
#   'sub_name': 'ADVOCACY RESOURCE CENTER MARION INC',
#   'subseccd': 3},
#  {'city': 'SARASOTA',
#   'ein': 651046019,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVOCATES FOR BETTER HEARING INC',
#   'ntee_code': 'P87',
#   'raw_ntee_code': 'P87',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-1046019',
#   'sub_name': 'ADVOCATES FOR BETTER HEARING INC',
#   'subseccd': 3},
#  {'city': 'PANAMA CITY',
#   'ein': 593106108,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ADVOCATES FOR CHILDREN INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3106108',
#   'sub_name': 'ADVOCATES FOR CHILDREN INC',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 650122422,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AERO-MODELERS OF PERRINE FLA AMPS RC INC',
#   'ntee_code': 'O50',
#   'raw_ntee_code': 'O50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0122422',
#   'sub_name': 'AERO-MODELERS OF PERRINE FLA AMPS RC INC',
#   'subseccd': 4},
#  {'city': 'TALLAHASSEE',
#   'ein': 271527095,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AEROSPACE ALLIANCE',
#   'ntee_code': 'S40',
#   'raw_ntee_code': 'S40',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1527095',
#   'sub_name': 'AEROSPACE ALLIANCE',
#   'subseccd': 6},
#  {'city': 'TARPON SPRINGS',
#   'ein': 593465302,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AFFORDABLE HOUSING FOUNDATION INC',
#   'ntee_code': 'L20',
#   'raw_ntee_code': 'L20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3465302',
#   'sub_name': 'AFFORDABLE HOUSING FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'PALMETTO BAY',
#   'ein': 550821437,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AFRICA-DIASPORA PARTNERSHIP FOR EMPOWERMENT & DEVELOPMENT INC',
#   'ntee_code': 'C12',
#   'raw_ntee_code': 'C12',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '55-0821437',
#   'sub_name': 'AFRICA-DIASPORA PARTNERSHIP FOR EMPOWERMENT & DEVELOPMENT INC',
#   'subseccd': 3},
#  {'city': 'SPRING HILL',
#   'ein': 593267981,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AFRICAN-AMERICAN CLUB OF HERNANDO INC',
#   'ntee_code': 'B82Z',
#   'raw_ntee_code': 'B82Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3267981',
#   'sub_name': 'AFRICAN-AMERICAN CLUB OF HERNANDO INC',
#   'subseccd': 3},
#  {'city': 'GREENACRES',
#   'ein': 472611227,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AFROQUENA DANCE CORP',
#   'ntee_code': 'A23',
#   'raw_ntee_code': 'A23',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '47-2611227',
#   'sub_name': 'AFROQUENA DANCE CORP',
#   'subseccd': 3},
#  {'city': 'PENSACOLA',
#   'ein': 275106072,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AGAINST HIV AIDS INC',
#   'ntee_code': 'G81',
#   'raw_ntee_code': 'G81',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-5106072',
#   'sub_name': 'AGAINST HIV AIDS INC ',
#   'subseccd': 3},
#  {'city': 'MOORE HAVEN',
#   'ein': 650721743,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AGAPE HOME INC',
#   'ntee_code': 'P73',
#   'raw_ntee_code': 'P73',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0721743',
#   'sub_name': 'AGAPE HOME INC',
#   'subseccd': 3},
#  {'city': 'EUSTIS',
#   'ein': 593221095,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AGAPE HOUSE MINISTRY INC',
#   'ntee_code': 'P80Z',
#   'raw_ntee_code': 'P80Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3221095',
#   'sub_name': 'AGAPE HOUSE MINISTRY INC',
#   'subseccd': 3},
#  {'city': 'OAKLAND PARK',
#   'ein': 651001222,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AGAPE INTERNATIONAL CHRISTIAN FELLOWSHIP INC',
#   'ntee_code': 'X20',
#   'raw_ntee_code': 'X20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-1001222',
#   'sub_name': 'AGAPE INTERNATIONAL CHRISTIAN FELLOWSHIP INC',
#   'subseccd': 3},
#  {'city': 'MILTON',
#   'ein': 593388600,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AGRICULTURAL INNOVATIONS AND RESEARCH INC',
#   'ntee_code': 'U50',
#   'raw_ntee_code': 'U50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3388600',
#   'sub_name': 'AGRICULTURAL INNOVATIONS AND RESEARCH INC',
#   'subseccd': 3},
#  {'city': 'KEY WEST',
#   'ein': 592678740,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AH OF MONROE COUNTY INC',
#   'ntee_code': 'G81Z',
#   'raw_ntee_code': 'G81Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-2678740',
#   'sub_name': 'AH OF MONROE COUNTY INC ',
#   'subseccd': 3},
#  {'city': 'MIAMI BEACH',
#   'ein': 203848253,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AHAVAS YISROEL CHARITABLE FOUNDATION',
#   'ntee_code': 'C19',
#   'raw_ntee_code': 'C19',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-3848253',
#   'sub_name': 'AHAVAS YISROEL CHARITABLE FOUNDATION',
#   'subseccd': 3},
#  {'city': 'VALRICO',
#   'ein': 592099030,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AHAVAT ISRAEL INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-2099030',
#   'sub_name': 'AHAVAT ISRAEL INC',
#   'subseccd': 3},
#  {'city': 'DAYTONA BEACH',
#   'ein': 593699587,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AHEPA 410 INC',
#   'ntee_code': 'L21',
#   'raw_ntee_code': 'L21',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3699587',
#   'sub_name': 'AHEPA 410 INC',
#   'subseccd': 3},
#  {'city': 'SURFSIDE',
#   'ein': 205363349,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AHIMSA PROJECT INC',
#   'ntee_code': 'B99',
#   'raw_ntee_code': 'B99',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-5363349',
#   'sub_name': 'AHIMSA PROJECT INC',
#   'subseccd': 3},
#  {'city': 'GAINESVILLE',
#   'ein': 593412308,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AHMED M AND FAWZIA A EL-MAHDAWY FOUNDATION INC',
#   'ntee_code': 'T20Z',
#   'raw_ntee_code': 'T20Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3412308',
#   'sub_name': 'AHMED M AND FAWZIA A EL-MAHDAWY FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 592870663,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIA JACKSONVILLE CHAPTER',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-2870663',
#   'sub_name': 'AIA JACKSONVILLE CHAPTER ',
#   'subseccd': 6},
#  {'city': 'WEST PALM BCH',
#   'ein': 753085395,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AID INTERNATIONAL INC',
#   'ntee_code': 'P99',
#   'raw_ntee_code': 'P99',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '75-3085395',
#   'sub_name': 'AID INTERNATIONAL INC',
#   'subseccd': 3},
#  {'city': 'PORT ST LUCIE',
#   'ein': 330950809,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIDS & INFECTIOUS DISEASE SCIENCE CENTER',
#   'ntee_code': 'A57',
#   'raw_ntee_code': 'A57',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '33-0950809',
#   'sub_name': 'AIDS & INFECTIOUS DISEASE SCIENCE CENTER',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 141834131,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIDS VACCINE RESEARCH INSTITUTE',
#   'ntee_code': 'H81',
#   'raw_ntee_code': 'H81',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '14-1834131',
#   'sub_name': 'AIDS VACCINE RESEARCH INSTITUTE',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 650980096,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIMM HIGHER INC',
#   'ntee_code': 'A60',
#   'raw_ntee_code': 'A60',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0980096',
#   'sub_name': 'AIMM HIGHER INC',
#   'subseccd': 3},
#  {'city': 'MARY ESTHER',
#   'ein': 591400823,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIR COMMANDO ASSOCIATION INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-1400823',
#   'sub_name': 'AIR COMMANDO ASSOCIATION INC',
#   'subseccd': 19},
#  {'city': 'PEMBROKE PNES',
#   'ein': 596150964,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIR CONDITIONING REFRGTNG HTG & PIPING IND HEALTH & WELFARE FUND',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-6150964',
#   'sub_name': 'AIR CONDITIONING REFRGTNG HTG & PIPING IND HEALTH & WELFARE '
#               'FUND ',
#   'subseccd': 9},
#  {'city': 'ORLANDO',
#   'ein': 597106828,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIR POLLUTION EDUCATIONAL & RESEARCH CHARITABLE REMNDR UNITRST',
#   'ntee_code': 'T20Z',
#   'raw_ntee_code': 'T20Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-7106828',
#   'sub_name': 'AIR POLLUTION EDUCATIONAL & RESEARCH CHARITABLE REMNDR UNITRST ',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 800010530,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AIRBOAT ASSOCIATION OF FLORIDA',
#   'ntee_code': 'N50',
#   'raw_ntee_code': 'N50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '80-0010530',
#   'sub_name': 'AIRBOAT ASSOCIATION OF FLORIDA',
#   'subseccd': 7},
#  {'city': 'FORT LAUDERDALE',
#   'ein': 650745178,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AJC CHILDRENS FOUNDATION INC',
#   'ntee_code': 'P20',
#   'raw_ntee_code': 'P20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0745178',
#   'sub_name': 'AJC CHILDRENS FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'APOPKA',
#   'ein': 742147678,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AL LACY CRUSADES INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '74-2147678',
#   'sub_name': 'AL LACY CRUSADES INC',
#   'subseccd': 3},
#  {'city': 'NAPLES',
#   'ein': 753187932,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AL-ANON FAMILY GROUPS FLORIDA SOUTH-AREA 10 INC',
#   'ntee_code': 'F21',
#   'raw_ntee_code': 'F21',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '75-3187932',
#   'sub_name': 'AL-ANON FAMILY GROUPS FLORIDA SOUTH-AREA 10 INC',
#   'subseccd': 3},
#  {'city': 'ORLANDO',
#   'ein': 465099190,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'AL-MAWRID UNITED STATES INC',
#   'ntee_code': 'X40',
#   'raw_ntee_code': 'X40',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '46-5099190',
#   'sub_name': 'AL-MAWRID UNITED STATES INC',
#   'subseccd': 3},
#  {'city': 'SANTA RSA BCH',
#   'ein': 636045638,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALABAMA ASSOCIATION OF HOUSING AND REDEVELOPMENT AUTHORITIES',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '63-6045638',
#   'sub_name': 'ALABAMA ASSOCIATION OF HOUSING AND REDEVELOPMENT AUTHORITIES',
#   'subseccd': 6},
#  {'city': 'GAINESVILLE',
#   'ein': 591908492,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALACHUA COUNTY HUMANE SOCIETY INC',
#   'ntee_code': 'D200',
#   'raw_ntee_code': 'D200',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-1908492',
#   'sub_name': 'ALACHUA COUNTY HUMANE SOCIETY INC',
#   'subseccd': 3},
#  {'city': 'BROOKER',
#   'ein': 591627845,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALACHUA COUNTY ORGANIZATION FOR RURAL NEEDS INC',
#   'ntee_code': 'E39Z',
#   'raw_ntee_code': 'E39Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-1627845',
#   'sub_name': 'ALACHUA COUNTY ORGANIZATION FOR RURAL NEEDS INC',
#   'subseccd': 3},
#  {'city': 'GAINESVILLE',
#   'ein': 593078903,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALACHUA COUNTY VETERANS MEMORIAL PROJECT COMMITTEE',
#   'ntee_code': 'A85Z',
#   'raw_ntee_code': 'A85Z',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3078903',
#   'sub_name': 'ALACHUA COUNTY VETERANS MEMORIAL PROJECT COMMITTEE',
#   'subseccd': 3},
#  {'city': 'PALM BEACH',
#   'ein': 592635536,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALAN H CUMMINGS FAMILY FOUNDATION INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-2635536',
#   'sub_name': 'ALAN H CUMMINGS FAMILY FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'DORAL',
#   'ein': 264484431,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALAS DE LIBERTAD CORPORATION',
#   'ntee_code': 'P50',
#   'raw_ntee_code': 'P50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-4484431',
#   'sub_name': 'ALAS DE LIBERTAD CORPORATION',
#   'subseccd': 3},
#  {'city': 'DORAL',
#   'ein': 464653969,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALAS SOLIDARIAS INC',
#   'ntee_code': 'E19',
#   'raw_ntee_code': 'E19',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '46-4653969',
#   'sub_name': 'ALAS SOLIDARIAS INC',
#   'subseccd': 3},
#  {'city': 'NAPLES',
#   'ein': 261603215,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERS-SCHONBERG FOUNDATION',
#   'ntee_code': 'T20',
#   'raw_ntee_code': 'T20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-1603215',
#   'sub_name': 'ALBERS-SCHONBERG FOUNDATION',
#   'subseccd': 3},
#  {'city': 'POMPANO BEACH',
#   'ein': 650983451,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERT AND BEATRIZ MINIACI FAMILY FOUNDATION INC',
#   'ntee_code': 'T20',
#   'raw_ntee_code': 'T20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0983451',
#   'sub_name': 'ALBERT AND BEATRIZ MINIACI FAMILY FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 342023275,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERT C PIERRE COMMUNITY SERVICE CENTER INC',
#   'ntee_code': 'S20',
#   'raw_ntee_code': 'S20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '34-2023275',
#   'sub_name': 'ALBERT C PIERRE COMMUNITY SERVICE CENTER INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 546033518,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERT F PATTON TRUST 04 410 6361737',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '54-6033518',
#   'sub_name': 'ALBERT F PATTON TRUST 04 410 6361737',
#   'subseccd': 92},
#  {'city': 'MIAMI',
#   'ein': 273971556,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERT H & JANE D NAHMAD FOUNDATION INC',
#   'ntee_code': 'T20',
#   'raw_ntee_code': 'T20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-3971556',
#   'sub_name': 'ALBERT H & JANE D NAHMAD FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'ST PETERSBURG',
#   'ein': 600004737,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERT WHITTED AIRPORT PRESERVATION SOCIETY INC',
#   'ntee_code': 'A80',
#   'raw_ntee_code': 'A80',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '60-0004737',
#   'sub_name': 'ALBERT WHITTED AIRPORT PRESERVATION SOCIETY INC',
#   'subseccd': 3},
#  {'city': 'WEST PALM BCH',
#   'ein': 133411143,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERTA AND HENRY STRAGE FOUNDATION',
#   'ntee_code': 'T20',
#   'raw_ntee_code': 'T20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '13-3411143',
#   'sub_name': 'ALBERTA AND HENRY STRAGE FOUNDATION',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 570918209,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERTINE MOORE SCHOLARSHIP FUND',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '57-0918209',
#   'sub_name': 'ALBERTINE MOORE SCHOLARSHIP FUND',
#   'subseccd': 3},
#  {'city': 'KEY BISCAYNE',
#   'ein': 271394499,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERTO AND OLGA MARIA BEECK FAMILY FOUNDATION',
#   'ntee_code': 'T22',
#   'raw_ntee_code': 'T22',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1394499',
#   'sub_name': 'ALBERTO AND OLGA MARIA BEECK FAMILY FOUNDATION',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 222872241,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALBERTO VOLLMER FOUNDATION INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '22-2872241',
#   'sub_name': 'ALBERTO VOLLMER FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 237410323,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALCOHOLIC REHAB INC',
#   'ntee_code': 'F22',
#   'raw_ntee_code': 'F22',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '23-7410323',
#   'sub_name': 'ALCOHOLIC REHAB INC',
#   'subseccd': 3},
#  {'city': 'PANAMA CITY BEACH',
#   'ein': 593710845,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALDRIDGE MINISTRIES INTERNATIONAL INC',
#   'ntee_code': 'X99',
#   'raw_ntee_code': 'X99',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3710845',
#   'sub_name': 'ALDRIDGE MINISTRIES INTERNATIONAL INC',
#   'subseccd': 3},
#  {'city': 'TAMPA',
#   'ein': 203690003,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEGRIA S KICKIN FOR KIDS INC',
#   'ntee_code': 'T30',
#   'raw_ntee_code': 'T30',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-3690003',
#   'sub_name': 'ALEGRIA S KICKIN FOR KIDS INC',
#   'subseccd': 3},
#  {'city': 'MARCO ISLAND',
#   'ein': 263923612,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEX DEL RIO FOUNDATION INC',
#   'ntee_code': 'B82',
#   'raw_ntee_code': 'B82',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-3923612',
#   'sub_name': 'ALEX DEL RIO FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'AVENTURA',
#   'ein': 237067927,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEXANDER KOURLAND MEMORIAL FOUNDATION',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '23-7067927',
#   'sub_name': 'ALEXANDER KOURLAND MEMORIAL FOUNDATION',
#   'subseccd': 3},
#  {'city': 'LAKE HAMILTON',
#   'ein': 271694104,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEXANDER MINISTRIES INTERNATIONAL INC',
#   'ntee_code': 'X20',
#   'raw_ntee_code': 'X20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1694104',
#   'sub_name': 'ALEXANDER MINISTRIES INTERNATIONAL INC ',
#   'subseccd': 3},
#  {'city': 'PALM BCH GDNS',
#   'ein': 650331597,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEXANDER W DREYFOOS JR CHARITABLE FOUNDATION INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0331597',
#   'sub_name': 'ALEXANDER W DREYFOOS JR CHARITABLE FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'FT LAUDERDALE',
#   'ein': 455585146,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALEXANDRIAN FORUM INC',
#   'ntee_code': 'X83',
#   'raw_ntee_code': 'X83',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '45-5585146',
#   'sub_name': 'ALEXANDRIAN FORUM INC',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 264783787,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALFONSO SORIANO FAMILY FOUNDATION INC',
#   'ntee_code': 'Q33',
#   'raw_ntee_code': 'Q33',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-4783787',
#   'sub_name': 'ALFONSO SORIANO FAMILY FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'CORAL GABLES',
#   'ein': 650565230,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALHAMBRA MUSIC INC',
#   'ntee_code': 'A68',
#   'raw_ntee_code': 'A68',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0565230',
#   'sub_name': 'ALHAMBRA MUSIC INC',
#   'subseccd': 3},
#  {'city': 'TAMPA',
#   'ein': 593393623,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALHAMDULILLAH COMMUNITY EDUCATIONAL CENTER INC',
#   'ntee_code': 'B90',
#   'raw_ntee_code': 'B90',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3393623',
#   'sub_name': 'ALHAMDULILLAH COMMUNITY EDUCATIONAL CENTER INC',
#   'subseccd': 3},
#  {'city': 'DELAND',
#   'ein': 208034843,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALIANZA DE MUJERES ACTIVAS INC',
#   'ntee_code': 'P80',
#   'raw_ntee_code': 'P80',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-8034843',
#   'sub_name': 'ALIANZA DE MUJERES ACTIVAS INC',
#   'subseccd': 3},
#  {'city': 'CORAL GABLES',
#   'ein': 263399558,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALIANZA NACIONAL CONSTITUCIONALISTA INC',
#   'ntee_code': 'Q70',
#   'raw_ntee_code': 'Q70',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-3399558',
#   'sub_name': 'ALIANZA NACIONAL CONSTITUCIONALISTA INC',
#   'subseccd': 3},
#  {'city': 'LONGBOAT KEY',
#   'ein': 650950239,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALICE AND ED BRICKMAN FAMILY TZEDUKAH FOUNDATION',
#   'ntee_code': 'T22',
#   'raw_ntee_code': 'T22',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0950239',
#   'sub_name': 'ALICE AND ED BRICKMAN FAMILY TZEDUKAH FOUNDATION ',
#   'subseccd': 3},
#  {'city': 'PONTE VEDRA',
#   'ein': 593074608,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALICE B LANDRUM MIDDLE SCHOOL PTO INC',
#   'ntee_code': 'B24I',
#   'raw_ntee_code': 'B24I',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3074608',
#   'sub_name': 'ALICE B LANDRUM MIDDLE SCHOOL PTO INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 596126472,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALICE GIVEANS WELSH TRUST',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-6126472',
#   'sub_name': 'ALICE GIVEANS WELSH TRUST ',
#   'subseccd': 92},
#  {'city': 'ORLANDO',
#   'ein': 526027464,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALICE RICHIE IRR TR 51 7023175',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '52-6027464',
#   'sub_name': 'ALICE RICHIE IRR TR 51 7023175 ',
#   'subseccd': 92},
#  {'city': 'BOCA RATON',
#   'ein': 271439593,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALIGN MINISTRY INC',
#   'ntee_code': 'X022',
#   'raw_ntee_code': 'X022',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1439593',
#   'sub_name': 'ALIGN MINISTRY INC',
#   'subseccd': 3},
#  {'city': 'SARASOTA',
#   'ein': 650115814,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL FAITHS FOOD BANK INC',
#   'ntee_code': 'K310',
#   'raw_ntee_code': 'K310',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0115814',
#   'sub_name': 'ALL FAITHS FOOD BANK INC',
#   'subseccd': 3},
#  {'city': 'BRADENTON',
#   'ein': 650733508,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL GODS CHILDREN INC',
#   'ntee_code': 'G81',
#   'raw_ntee_code': 'G81',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0733508',
#   'sub_name': 'ALL GODS CHILDREN INC',
#   'subseccd': 3},
#  {'city': 'LOXAHATCHEE',
#   'ein': 472974916,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL IN SPORTS AND FITNESS INC',
#   'ntee_code': 'T50',
#   'raw_ntee_code': 'T50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '47-2974916',
#   'sub_name': 'ALL IN SPORTS AND FITNESS INC',
#   'subseccd': 3},
#  {'city': 'PALMETTO',
#   'ein': 454468199,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL KITTY KORNER INC',
#   'ntee_code': 'D20',
#   'raw_ntee_code': 'D20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '45-4468199',
#   'sub_name': 'ALL KITTY KORNER INC ',
#   'subseccd': 3},
#  {'city': 'DELTONA',
#   'ein': 450659124,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL NATIONS CHRISTIAN CENTER INC',
#   'ntee_code': 'X21',
#   'raw_ntee_code': 'X21',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '45-0659124',
#   'sub_name': 'ALL NATIONS CHRISTIAN CENTER INC',
#   'subseccd': 3},
#  {'city': 'TALLAHASSEE',
#   'ein': 204707700,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL SAINTS ANGLICAN CHURCH OF TALLAHASSEE INC',
#   'ntee_code': 'X21',
#   'raw_ntee_code': 'X21',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-4707700',
#   'sub_name': 'ALL SAINTS ANGLICAN CHURCH OF TALLAHASSEE INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 591500774,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL SAINTS EARLY LEARNING AND COMMUNITY CARE CENTER INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-1500774',
#   'sub_name': 'ALL SAINTS EARLY LEARNING AND COMMUNITY CARE CENTER INC',
#   'subseccd': 3},
#  {'city': 'FT WALTON BCH',
#   'ein': 593224296,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL SPORTS ASSOCIATION INC',
#   'ntee_code': 'N60',
#   'raw_ntee_code': 'N60',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3224296',
#   'sub_name': 'ALL SPORTS ASSOCIATION INC',
#   'subseccd': 3},
#  {'city': 'SUNRISE',
#   'ein': 861091908,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL SPORTS ATHLETIC ASSOCIATION INC',
#   'ntee_code': 'O50',
#   'raw_ntee_code': 'O50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '86-1091908',
#   'sub_name': 'ALL SPORTS ATHLETIC ASSOCIATION INC',
#   'subseccd': 3},
#  {'city': 'SARASOTA',
#   'ein': 202182079,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL STAR CHILDRENS FOUNDATION INC',
#   'ntee_code': 'T12',
#   'raw_ntee_code': 'T12',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '20-2182079',
#   'sub_name': 'ALL STAR CHILDRENS FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'ORLANDO',
#   'ein': 593695554,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL STAR SERVICE CENTER CONDOMINUM ASSOCIATION INC',
#   'ntee_code': 'L50',
#   'raw_ntee_code': 'L50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3695554',
#   'sub_name': 'ALL STAR SERVICE CENTER CONDOMINUM ASSOCIATION INC',
#   'subseccd': 4},
#  {'city': 'ORLANDO',
#   'ein': 471301389,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL STARS ARE BRIGHT CORPORATION',
#   'ntee_code': 'O50',
#   'raw_ntee_code': 'O50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '47-1301389',
#   'sub_name': 'ALL STARS ARE BRIGHT CORPORATION',
#   'subseccd': 3},
#  {'city': 'LEHIGH ACRES',
#   'ein': 412086582,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL THE CHILDREN ARE CHILDREN INC',
#   'ntee_code': 'B24',
#   'raw_ntee_code': 'B24',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '41-2086582',
#   'sub_name': 'ALL THE CHILDREN ARE CHILDREN INC',
#   'subseccd': 3},
#  {'city': 'JACKSONVILLE',
#   'ein': 900939012,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL THINGS NEW INC',
#   'ntee_code': 'Q33',
#   'raw_ntee_code': 'Q33',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '90-0939012',
#   'sub_name': 'ALL THINGS NEW INC',
#   'subseccd': 3},
#  {'city': 'JAY',
#   'ein': 472088058,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL THINGS NEW MINISTRIES OF JAY FLORIDA INC',
#   'ntee_code': 'X20',
#   'raw_ntee_code': 'X20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '47-2088058',
#   'sub_name': 'ALL THINGS NEW MINISTRIES OF JAY FLORIDA INC',
#   'subseccd': 3},
#  {'city': 'HOLLYWOOD',
#   'ein': 271198651,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALL-STAR CLASSIC INC',
#   'ntee_code': 'Z99',
#   'raw_ntee_code': 'Z99',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1198651',
#   'sub_name': 'ALL-STAR CLASSIC INC',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 650923065,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLEN CHAPEL AME FOUNDATION INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0923065',
#   'sub_name': 'ALLEN CHAPEL AME FOUNDATION INC',
#   'subseccd': 3},
#  {'city': 'PENSACOLA',
#   'ein': 593749697,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLEN COMMUNITY DEVELOPMENT AND SERVICE CENTER INC',
#   'ntee_code': 'P20',
#   'raw_ntee_code': 'P20',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3749697',
#   'sub_name': 'ALLEN COMMUNITY DEVELOPMENT AND SERVICE CENTER INC',
#   'subseccd': 3},
#  {'city': 'MIAMI',
#   'ein': 562666652,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE FOR EARLY CARE AND EDUCATION INC',
#   'ntee_code': 'P30',
#   'raw_ntee_code': 'P30',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '56-2666652',
#   'sub_name': 'ALLIANCE FOR EARLY CARE AND EDUCATION INC',
#   'subseccd': 3},
#  {'city': 'ALTAMONTE SPG',
#   'ein': 263047816,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE FOR NEIGHBORS INC',
#   'ntee_code': 'L50',
#   'raw_ntee_code': 'L50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-3047816',
#   'sub_name': 'ALLIANCE FOR NEIGHBORS INC',
#   'subseccd': 3},
#  {'city': 'ST PETERSBURG',
#   'ein': 263597828,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE FOR WEEDON ISLAND ARCHAEOLOGICAL RESEARCH AND EDUCAT',
#   'ntee_code': 'A027',
#   'raw_ntee_code': 'A027',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-3597828',
#   'sub_name': 'ALLIANCE FOR WEEDON ISLAND ARCHAEOLOGICAL RESEARCH AND EDUCAT',
#   'subseccd': 3},
#  {'city': 'LANTANA',
#   'ein': 271720459,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE FRANCOPHONE OF PALM BEACHES INC',
#   'ntee_code': 'A23',
#   'raw_ntee_code': 'A23',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '27-1720459',
#   'sub_name': 'ALLIANCE FRANCOPHONE OF PALM BEACHES INC',
#   'subseccd': 3},
#  {'city': 'TAVARES',
#   'ein': 263959934,
#   'has_subseccd': True,
#   'have_extracts': True,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE OF DIVINE LOVE INC',
#   'ntee_code': 'P50',
#   'raw_ntee_code': 'P50',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '26-3959934',
#   'sub_name': 'ALLIANCE OF DIVINE LOVE INC ',
#   'subseccd': 3},
#  {'city': 'CASSELBERRY',
#   'ein': 593433342,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE OF DIVINE LOVE INC',
#   'ntee_code': 'X21',
#   'raw_ntee_code': 'X21',
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '59-3433342',
#   'sub_name': 'ALLIANCE OF DIVINE LOVE INC ',
#   'subseccd': 3},
#  {'city': 'TEQUESTA',
#   'ein': 650801660,
#   'has_subseccd': True,
#   'have_extracts': False,
#   'have_filings': True,
#   'have_pdfs': True,
#   'name': 'ALLIANCE OF DIVINE LOVE INC',
#   'ntee_code': None,
#   'raw_ntee_code': None,
#   'score': 4.2835336,
#   'state': 'FL',
#   'strein': '65-0801660',
#   'sub_name': 'ALLIANCE OF DIVINE LOVE INC ',
#   'subseccd': 3}]

# %%
df.head()
# Out:
#    api_version  cur_page                                        data_source  \
# 0            2         0  ProPublica Nonprofit Explorer API: https://pro...
# 1            2         0  ProPublica Nonprofit Explorer API: https://pro...
# 2            2         0  ProPublica Nonprofit Explorer API: https://pro...
# 3            2         0  ProPublica Nonprofit Explorer API: https://pro...
# 4            2         0  ProPublica Nonprofit Explorer API: https://pro...
#
#                                                error  num_pages  \
# 0  WARNING: Version 2 of the ProPublica Nonprofit...        440
# 1  WARNING: Version 2 of the ProPublica Nonprofit...        440
# 2  WARNING: Version 2 of the ProPublica Nonprofit...        440
# 3  WARNING: Version 2 of the ProPublica Nonprofit...        440
# 4  WARNING: Version 2 of the ProPublica Nonprofit...        440
#
#                                        organizations  page_offset  per_page  \
# 0  {'ein': 562342625, 'strein': '56-2342625', 'na...            0       100
# 1  {'ein': 593068740, 'strein': '59-3068740', 'na...            0       100
# 2  {'ein': 591756721, 'strein': '59-1756721', 'na...            0       100
# 3  {'ein': 261211203, 'strein': '26-1211203', 'na...            0       100
# 4  {'ein': 800364095, 'strein': '80-0364095', 'na...            0       100
#
#   search_query selected_code selected_ntee selected_state  total_results
# 0         None          None          None             FL          43941
# 1         None          None          None             FL          43941
# 2         None          None          None             FL          43941
# 3         None          None          None             FL          43941
# 4         None          None          None             FL          43941
